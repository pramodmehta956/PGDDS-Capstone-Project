# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodmehta956/PGDDS-Capstone-Project/blob/main/pramod_summariser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bert-extractive-summarizer

from summarizer import Summarizer
from transformers import pipeline

extractive_model = Summarizer()

text = 'Above project schedule is as indicative and planned. It is possible that during the project execution, the actual project/delivery schedule will be revised and it gets extended or delayed for reasons or factors not attributable to or controllable by Infosys. There could be early launches expected as per LIC and NEWGEN will be expected to adhere to Infosys Limited for supporting these early launches. In case of such delays or extensions, Infosys will promptly inform NEWGEN and agree on adjustments to be made to '

extractive_summary = extractive_model(text) #Corrected this line

abstractive_model = pipeline('summarization', model = 'MikaSie/RoBERTa_Llama3_dependent_V2', tokenizer = 'MikaSie/RoBERTa_Llama3_dependent_V2')

result = abstractive_model(text, max_length=130, min_length=30, do_sample=False) #Corrected this line
from transformers import pipeline

extractive_model = Summarizer()

text = 'Above project schedule is as indicative and planned. It is possible that during the project execution, the actual project/delivery schedule will be revised and it gets extended or delayed for reasons or factors not attributable to or controllable by Infosys. There could be early launches expected as per LIC and NEWGEN will be expected to adhere to Infosys Limited for supporting these early launches. In case of such delays or extensions, Infosys will promptly inform NEWGEN and agree on adjustments to be made to '

extractive_summary = Summarizer(text)

abstractive_model = pipeline('summarization', model = 'MikaSie/RoBERTa_Llama3_dependent_V2', tokenizer = 'MikaSie/RoBERTa_Llama3_dependent_V2')

result = pipeline(extractive_summary)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ...

# %%
# !pip install transformers accelerate
# !pip install bert-extractive-summarizer
# !pip install huggingface_hub

from summarizer import Summarizer
from transformers import pipeline
from huggingface_hub import login # Import the login function

# Log in to your Hugging Face account
login(token="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")  # Replace YOUR_HUGGINGFACE_TOKEN with your actual token

extractive_model = Summarizer()

text = 'Above project schedule is as indicative and planned. It is possible that during the project execution, the actual project/delivery schedule will be revised and it gets extended or delayed for reasons or factors not attributable to or controllable by Infosys. There could be early launches expected as per LIC and NEWGEN will be expected to adhere to Infosys Limited for supporting these early launches. In case of such delays or extensions, Infosys will promptly inform NEWGEN and agree on adjustments to be made to '

extractive_summary = extractive_model(text)

abstractive_model = pipeline('summarization', model = 'MikaSie/RoBERTa_Llama3_dependent_V2', tokenizer = 'MikaSie/RoBERTa_Llama3_dependent_V2')

result = abstractive_model(text, max_length=130, min_length=30, do_sample=False)
# Out:
# ...
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ...

# %%
# !pip install bert-extractive-summarizer
# !pip install huggingface_hub

from summarizer import Summarizer
from transformers import pipeline
from huggingface_hub import login # Import the login function

# Log in to your Hugging Face account - This is still recommended for rate limiting purposes
login(token="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")  # Replace YOUR_HUGGINGFACE_TOKEN with your actual token

# !pip install bert-extractive-summarizer
# !pip install huggingface_hub

from summarizer import Summarizer
from transformers import pipeline
from huggingface_hub import login # Import the login function

# Log in to your Hugging Face account - This is still recommended for rate limiting purposes
login(token="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")  # Replace YOUR_HUGGINGFACE_TOKEN with your actual token

extractive_model = Summarizer()

text = 'Initiation- Claims would be initiated in Customer Super App, Sales Super App and Digital Branch Interface and then routed to Claims Management solution (built on NewgenOne platform) for workflow processing. Required APIs for integration with these applications to be provided by SI/Client.\
ii.	Solution supports processing of Death and Health Claims, Maturity & Survival Benefit Claims. \
iii.	Advanced workflow to integrate claim investigators, CMO, UW and different level supervisor for approval.\
iv.	Ability for Online verification of Death Certificate through third party integration\
v.	Policy life cycle value by calculating maturity value, surrender value.\
vi.	Communication to claimant at various claim stages through email/SMSs.\
vii.	Ability to cater to maturity and annuity payouts.\
viii.	Ability to perform process specific calculations such as Penal interest, TDS amount etc. \
ix.	All product specific details will be fetched from the Core Application (eFeap- Next).'


extractive_summary = extractive_model(text)

# Use a publicly available model for abstractive summarization
abstractive_model = pipeline('summarization', model='facebook/bart-large-cnn')

# !pip install bert-extractive-summarizer
# !pip install huggingface_hub

from summarizer import Summarizer
from transformers import pipeline
from huggingface_hub import login # Import the login function

# Log in to your Hugging Face account - This is still recommended for rate limiting purposes
login(token="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")  # Replace YOUR_HUGGINGFACE_TOKEN with your actual token

extractive_model = Summarizer()

text = 'Initiation- Claims would be initiated in Customer Super App, Sales Super App and Digital Branch Interface and then routed to Claims Management solution (built on NewgenOne platform) for workflow processing. Required APIs for integration with these applications to be provided by SI/Client.\
ii.	Solution supports processing of Death and Health Claims, Maturity & Survival Benefit Claims. \
iii.	Advanced workflow to integrate claim investigators, CMO, UW and different level supervisor for approval.\
iv.	Ability for Online verification of Death Certificate through third party integration\
v.	Policy life cycle value by calculating maturity value, surrender value.\
vi.	Communication to claimant at various claim stages through email/SMSs.\
vii.	Ability to cater to maturity and annuity payouts.\
viii.	Ability to perform process specific calculations such as Penal interest, TDS amount etc. \
ix.	All product specific details will be fetched from the Core Application (eFeap- Next).'


extractive_summary = extractive_model(text)

# Use a publicly available model for abstractive summarization
abstractive_model = pipeline('summarization', model='facebook/bart-large-cnn')

result = abstractive_model(text, max_length=230, min_length=30, do_sample=False)
print(result)
# !pip install bert-extractive-summarizer
# !pip install huggingface_hub

from summarizer import Summarizer
from transformers import pipeline
from huggingface_hub import login # Import the login function

# Log in to your Hugging Face account - This is still recommended for rate limiting purposes
login(token="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")  # Replace YOUR_HUGGINGFACE_TOKEN with your actual token

extractive_model = Summarizer()

text = 'Initiation- Claims would be initiated in Customer Super App, Sales Super App and Digital Branch Interface and then routed to Claims Management solution (built on NewgenOne platform) for workflow processing. Required APIs for integration with these applications to be provided by SI/Client.\
ii.	Solution supports processing of Death and Health Claims, Maturity & Survival Benefit Claims. \
iii.	Advanced workflow to integrate claim investigators, CMO, UW and different level supervisor for approval.\
iv.	Ability for Online verification of Death Certificate through third party integration\
v.	Policy life cycle value by calculating maturity value, surrender value.\
vi.	Communication to claimant at various claim stages through email/SMSs.\
vii.	Ability to cater to maturity and annuity payouts.\
viii.	Ability to perform process specific calculations such as Penal interest, TDS amount etc. \
ix.	All product specific details will be fetched from the Core Application (eFeap- Next).'


extractive_summary = extractive_model(text)

# Use a publicly available model for abstractive summarization
abstractive_model = pipeline('summarization', model='facebook/bart-large-cnn')

result = abstractive_model(text, max_length=230, min_length=30, do_sample=False)
print(result)
extractive_summary = extractive_model(text)

# Use a publicly available model for abstractive summarization
abstractive_model = pipeline('summarization', model='facebook/bart-large-cnn')

result = abstractive_model(text, max_length=230, min_length=30, do_sample=False)
print(result)
# Out:
# ...
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# ...
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# ...
